# %%
import os

# %%
folder = "/content/drive/MyDrive/Detecting/valid/Tomato___healthy";

# %%
for cnt,i in enumerate(os.listdir(folder)):
  # dst = f"TomatoHealthy{str(cnt)}.jpg"
  # src =f"{folder}/{i}"
  # dst =f"{folder}/{dst}"
  # os.rename(src, dst)
  print(cnt,i)
# Out:
# 0 TomatoHealthy0.jpg
# 1 TomatoHealthy1.jpg
# 2 TomatoHealthy2.jpg
# 3 TomatoHealthy3.jpg
# 4 TomatoHealthy4.jpg
# 5 TomatoHealthy5.jpg
# 6 TomatoHealthy6.jpg
# 7 TomatoHealthy7.jpg
# 8 TomatoHealthy8.jpg
# 9 TomatoHealthy9.jpg
# 10 TomatoHealthy10.jpg
# 11 TomatoHealthy11.jpg
# 12 TomatoHealthy12.jpg
# 13 TomatoHealthy13.jpg
# 14 TomatoHealthy14.jpg
# 15 TomatoHealthy15.jpg
# 16 TomatoHealthy16.jpg
# 17 TomatoHealthy17.jpg
# 18 TomatoHealthy18.jpg
# 19 TomatoHealthy19.jpg
# 20 TomatoHealthy20.jpg
# 21 TomatoHealthy21.jpg
# 22 TomatoHealthy22.jpg
# 23 TomatoHealthy23.jpg
# 24 TomatoHealthy24.jpg
# 25 TomatoHealthy25.jpg
# 26 TomatoHealthy26.jpg
# 27 TomatoHealthy27.jpg
# 28 TomatoHealthy28.jpg
# 29 TomatoHealthy29.jpg
# 30 TomatoHealthy30.jpg
# 31 TomatoHealthy31.jpg
# 32 TomatoHealthy32.jpg
# 33 TomatoHealthy33.jpg
# 34 TomatoHealthy34.jpg
# 35 TomatoHealthy35.jpg
# 36 TomatoHealthy36.jpg
# 37 TomatoHealthy37.jpg
# 38 TomatoHealthy38.jpg
# 39 TomatoHealthy39.jpg
# ...

# %%
for cnt,i in enumerate(os.listdir(folder)):
  print(cnt,i)
# Out:
# 0 Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 1 Tomato___Bacterial_spot
# 2 Tomato___Spider_mites Two-spotted_spider_mite
# 3 Tomato___Target_Spot
# 4 Tomato___Early_blight
# 5 Tomato___healthy
# 6 Tomato___Late_blight
# 7 Tomato___Leaf_Mold
# 8 Tomato___Septoria_leaf_spot
# 9 Tomato___Tomato_mosaic_virus
