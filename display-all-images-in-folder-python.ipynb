# %% [markdown]
# code to: Display all the images from a folder

# %% [markdown]
# steps
# 1. Access the folder/ path ----os
# 2. Read the images --- opencv---cv2--imread()
# 3. display ---matplotlit--- imshow()

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
#path
path="C:/Users/Rajat/Desktop/Testing"
images=os.listdir(path) 
type(images)
len(images)
# Out:
# 10

# %%
img_data=[]
for img in images:
    img_arr=cv2.imread(os.path.join(path,img))
    img_data.append(img_arr)

# %%
fig = plt.figure(figsize=(150,150))
columns = 1 
for i in range(len(img_data)):
    ax = fig.add_subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(img_data[i])
    ax.set_title('axes title')
#     plt.suptitle('bold figure suptitle', fontsize=14, fontweight='bold')
    plt.xticks([])
    plt.yticks([])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 4
#       2 columns = 1
#       3 for i in range(len(img_data)):
# ----> 4     ax = fig.add_subplot(len(images) / columns + 1, columns, i + 1)
#       5     plt.imshow(img_data[i])
#       6     ax.set_title('axes title')
#
# File ~\lib\site-packages\matplotlib\figure.py:772, in FigureBase.add_subplot(self, *args, **kwargs)
#     769         args = tuple(map(int, str(args[0])))
#     770     projection_class, pkw = self._process_projection_requirements(
#     771         *args, **kwargs)
# --> 772     ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773     key = (projection_class, pkw)
#     774 return self._add_axes_internal(ax, key)
#
# File ~\lib\site-packages\matplotlib\axes\_subplots.py:36, in SubplotBase.__init__(self, fig, *args, **kwargs)
# ...

# %%
# import matplotlib
# import matplotlib.pyplot as plt


# ax = fig.add_subplot()


# # Set titles for the figure and the subplot respectively
# fig.suptitle('bold figure suptitle', fontsize=14, fontweight='bold')
# ax.set_title('axes title')

# plt.show()

# %%
# import required module
import glob
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

# get the path/directory
folder_dir = "C:/Users/Rajat/Desktop/Testing/"

# iterate over files in
# that directory
for images in glob.iglob(f'{folder_dir}/*'):

    # check if the image ends with png
#     if (images.endswith(".JPG")):
#         print(images)

 
    plt.title("Sheep Image")
#     plt.xlabel("X pixel scaling")
#     plt.ylabel("Y pixels scaling")
 
    image = mpimg.imread(images)
    plt.imshow(image)
    plt.show()

# %%
# import glob
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# %matplotlib inline

# images = []
# for img_path in glob.glob("C:/Users/Rajat/Desktop/Testing/*JPG"):
#     images.append(mpimg.imread(img_path))

# plt.figure(figsize=(128,128))
# columns = 1
# for i, image in enumerate(images):
#     plt.subplot(len(images) / columns + 1, columns, i + 1)
#     plt.imshow(image)
#     plt.xticks([])
#     plt.yticks([])

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
 
plt.title("Sheep Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")
 
image = mpimg.imread("C:/Users/Rajat/Desktop/Testing/01f87f04-ff38-4aba-b7d1-587aa06e5282___RS_Erly.B 7851.JPG")
plt.imshow(image)
plt.show()
